# %% [markdown]
# ## Analyzing and Picking top 5 Stocks

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# read csv file 
stocks = pd.read_csv('../data/stocks_closing_info_2015.csv').set_index('Ticker Symbol').round(2)
stocks
# Out:
#               Period Ending    Net Income  Profit Margin  Quick Ratio  \
# Ticker Symbol
# AAL              2015-12-31  7.610000e+09           19.0         67.0
# ABBV             2015-12-31  5.144000e+09           23.0        134.0
# ABT              2015-12-31  4.423000e+09           22.0        126.0
# ADM              2015-12-31  1.849000e+09            3.0        101.0
# ADS              2015-12-31  5.965410e+08            9.0        254.0
# ...                     ...           ...            ...          ...
# XYL              2015-12-31  3.400000e+08            9.0        191.0
# YHOO             2015-12-31 -4.359082e+09           88.0        588.0
# ZBH              2015-12-31  1.470000e+08            2.0        223.0
# ZION             2015-12-31  3.094710e+08           14.0          NaN
# ZTS              2015-12-31  3.390000e+08            7.0        133.0
#
#                Total Assets  Total Liabilities  Earnings Per Share  \
# Ticker Symbol
# ...

# %%
# Filter list to stock price is smaller than $100
priced_filtered = stocks.loc[
    stocks['Closing Price'] < 100,
    :
]

# %%
priced_filtered
# Out:
#               Period Ending    Net Income  Profit Margin  Quick Ratio  \
# Ticker Symbol
# AAL              2015-12-31  7.610000e+09           19.0         67.0
# ABBV             2015-12-31  5.144000e+09           23.0        134.0
# ABT              2015-12-31  4.423000e+09           22.0        126.0
# ADM              2015-12-31  1.849000e+09            3.0        101.0
# AEE              2015-12-31  6.360000e+08           10.0         66.0
# ...                     ...           ...            ...          ...
# XRX              2015-12-31  4.740000e+08            3.0        109.0
# XYL              2015-12-31  3.400000e+08            9.0        191.0
# YHOO             2015-12-31 -4.359082e+09           88.0        588.0
# ZION             2015-12-31  3.094710e+08           14.0          NaN
# ZTS              2015-12-31  3.390000e+08            7.0        133.0
#
#                Total Assets  Total Liabilities  Earnings Per Share  \
# Ticker Symbol
# ...

# %% [markdown]
# ## Working Capital Ratio
#
# - Deciding which company stocks are more liquide
#
# - Ratio should be between 1.5- 2

# %%
# working capital ratio = current assets / current liabilities
priced_filtered['Working Capital Ratio'] = priced_filtered['Total Current Assets'] / priced_filtered['Total Current Liabilities']
# Out:
# <ipython-input-6-953dcb37f02f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priced_filtered['Working Capital Ratio'] = priced_filtered['Total Current Assets'] / priced_filtered['Total Current Liabilities']

# %%
working_capital = pd.DataFrame(priced_filtered['Working Capital Ratio']).sort_values(by='Working Capital Ratio', ascending=False).round(2)

working_capital_top = working_capital.loc[
    priced_filtered['Working Capital Ratio'] <= 2,
    :
]
working_capital_top.head()
# Out:
#                Working Capital Ratio
# Ticker Symbol
# MAT                             1.94
# PWR                             1.89
# DVA                             1.88
# FBHS                            1.87
# PNR                             1.87

# %%
working_capital = priced_filtered['Working Capital Ratio']

# %% [markdown]
# ## Quick Ratio
#
# - Considered to be more consertvative than current ratio
#
# - The higher the ratio result, the better a company's liquidity

# %%
quick_ratio = pd.DataFrame(priced_filtered['Quick Ratio']).sort_values(by='Quick Ratio', ascending=False).round(2)
quick_ratio.head()
# Out:
#                Quick Ratio
# Ticker Symbol
# YHOO                 588.0
# FTR                  535.0
# AKAM                 377.0
# EW                   359.0
# EBAY                 349.0

# %%
quick_ratio = priced_filtered['Quick Ratio']

# %% [markdown]
# ## Earnings Per Share (EPS)
#
# - A higher EPS indicates greater value because investors will pay more for a company's shares if they think the company has higher profits relative to its share price.

# %%
earnings_per_share = pd.DataFrame(priced_filtered['Earnings Per Share']).sort_values(by='Earnings Per Share', ascending=False).round(2)
earnings_per_share.head()
# Out:
#                Earnings Per Share
# Ticker Symbol
# UAL                         19.52
# PRU                         12.37
# AAL                         11.39
# LVLT                         9.71
# LYB                          9.62

# %%
eps = priced_filtered['Earnings Per Share']

# %% [markdown]
# ## Price to Earnings Ratio (P/E)
#
# - Investors expect higher earnings with higher P/E

# %%
# Earnings Per Share/ closing price = percentage - top 5 stocks 
priced_filtered['P/E Ratio'] = priced_filtered['Closing Price']/priced_filtered['Earnings Per Share'] 
earnings_vs_closing = pd.DataFrame(priced_filtered['P/E Ratio']).sort_values(by='P/E Ratio', ascending=False).head()
earnings_vs_closing['P/E Ratio'] = earnings_vs_closing['P/E Ratio'].map(" {:,.2f}".format)
earnings_vs_closing
# Out:
# <ipython-input-13-9637069dea7a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priced_filtered['P/E Ratio'] = priced_filtered['Closing Price']/priced_filtered['Earnings Per Share']
#               P/E Ratio
# Ticker Symbol
# CXO              169.59
# KMI              145.40
# EQT               91.80
# SE                81.83
# BMY               73.96

# %%
pe_ratio = priced_filtered['Closing Price']/priced_filtered['Earnings Per Share']

# %% [markdown]
# ## Debt to Equity ratio
#
# The optimal debt-to-equity ratio will tend to vary widely by industry, but the general consensus is that it should not be above a level of 2.0.

# %%
# Find shareholders equity
priced_filtered['Shareholders Equity'] = priced_filtered['Total Assets']-priced_filtered['Total Liabilities']
# Out:
# <ipython-input-30-df0f2d97066c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priced_filtered['Shareholders Equity'] = priced_filtered['Total Assets']-priced_filtered['Total Liabilities']

# %%
# Debt to equity is total liabilities / Shareholder Equity
priced_filtered['D/E Ratio'] = priced_filtered['Total Liabilities'] / priced_filtered['Shareholders Equity']
# Out:
# <ipython-input-33-2e33f48dcbc1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   priced_filtered['D/E Ratio'] = priced_filtered['Total Liabilities'] / priced_filtered['Shareholders Equity']

# %%
# D/E should not be above 2 - 5 top slowest stocks 
debt_vs_equity = pd.DataFrame(priced_filtered['D/E Ratio']).sort_values(by='D/E Ratio', ascending=True).round(2).head()
debt_vs_equity
# Out:
#                D/E Ratio
# Ticker Symbol
# WYNN              -94.97
# MAS               -42.96
# CL                -40.99
# IDXX              -18.53
# MJN                -7.32

# %%
profit_margin = priced_filtered['Profit Margin']
closing_price = priced_filtered['Closing Price']

# %%
# create a new dataframe with only the information we need 
final_table = pd.DataFrame({
    'Stock Price': closing_price,
    'Profit Margin': profit_margin,
    'Working Capital Ratio': working_capital,
    'Quick Ratio': quick_ratio,
    'Earning Per Share': eps,
    'P/E Ratio': pe_ratio,
    'D/E Ratio': de_ratio                      
})

final_table
# Out:
#                Stock Price  Profit Margin  Working Capital Ratio  Quick Ratio  \
# Ticker Symbol
# AAL                  42.80           19.0               0.733921         67.0
# ABBV                 59.80           23.0               1.497522        134.0
# ABT                  45.27           22.0               1.540932        126.0
# ADM                  36.88            3.0               1.616364        101.0
# AEE                  44.00           10.0               0.915910         66.0
# ...                    ...            ...                    ...          ...
# XRX                  10.72            3.0               1.272364        109.0
# XYL                  36.87            9.0               2.436209        191.0
# YHOO                 33.37           88.0               5.877123        588.0
# ZION                 27.47           14.0                    NaN          NaN
# ZTS                  48.26            7.0               2.150477        133.0
#
# ...

# %% [markdown]
# ## Ranking
#
# - We decided to rank the stocks by:
#     - Profit Margin = %10
#     - Working Capital Ratio = %35
#     - Quick Ratio = %10
#     - EPS = %30
#     - D/E Ratio = %25

# %%
# find the stock's ranking to find the top 5 stocks 
final_table['Ranking'] = (0.10*final_table['Quick Ratio']+
                          0.10*final_table['Profit Margin']+
                          0.35*final_table['Working Capital Ratio']+
                          0.30*final_table['Earning Per Share']+ 
                          0.25*final_table['D/E Ratio']
)
                        

top_stocks = final_table.sort_values(by='Ranking', ascending=False).round(2)
top_stocks
# Out:
#                Stock Price  Profit Margin  Working Capital Ratio  Quick Ratio  \
# Ticker Symbol
# YHOO                 33.37           88.0                   5.88        588.0
# FTR                   4.66            4.0                   5.35        535.0
# AKAM                 52.90           15.0                   3.77        377.0
# EW                   79.21           20.0                   4.30        359.0
# EBAY                 27.75           20.0                   3.49        349.0
# ...                    ...            ...                    ...          ...
# UNM                  33.52            8.0                    NaN          NaN
# VTR                  56.63           13.0                    NaN          NaN
# WFC                  54.89           25.0                    NaN          NaN
# XL                   39.82           13.0                    NaN          NaN
# ZION                 27.47           14.0                    NaN          NaN
#
# ...

# %%
top_stocks.to_csv("../data/top_stocks.csv")
